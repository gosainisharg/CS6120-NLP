# %% [markdown]
# Homework 1: Python, Strings, Data, Scale
# ----
#
# Due date: Jan 19th, 2024, 11:59 PM
#
# Points: 42
#
# Files to submit:
# - `data_scale.ipynb`
# - `yourdatafilefortask3and4` (See task 3. This file will most likely be a `.txt` or `.csv`, but can be any)
#
# Goals:
# - ensure that your python environment is set up and running
# - learn/review python skills regarding `string`s, data structures, and file manipulation
#
# Complete in groups of: __one (individually)__
#
# Allowed python modules:
# - Note that all necessary modules have already been imported for you for this assignment. (you may import any standard python libraries, plotting libraries as you'd like)
#
#
# Instructions:
# - Complete outlined problems in this notebook.
# - When you have finished, __clear the kernel__ and run your notebook "fresh" from top to bottom. Ensure that there are __no errors__.
#     - If a problem asks for you to write code that does result in an error (as in, the answer to the problem is an error), leave the code in your notebook but commented out so that running from top to bottom does not result in any errors.
# - Double check that you have completed Task 0.
# - Submit your work on Gradescope.
# - Double check that your submission on Gradescope looks like you believe it should.

# %% [markdown]
# Task 0: Name, References, Reflection (5 points)
# ---
#
# **TODO:** complete this section
#
# **Name: Nisharg Gosai**
#
# References
# ---
# List the resources you consulted to complete this homework here. Write one sentence per resource about what it provided to you. If you consulted no references to complete your assignment, write a brief sentence stating that this is the case and why it was the case for you.
#
# (Example)
# - https://docs.python.org/3/tutorial/datastructures.html
#     - Read about the the basics and syntax for data structures in python.
#
# - https://www.w3schools.com/python/python_lists.asp
#     - Quick review of lists
#
# - https://www.kaggle.com/datasets/rmisra/news-headlines-dataset-for-sarcasm-detection
#     - Got my dataset from Kaggle
#
# - https://stackoverflow.com/questions/952914/how-do-i-make-a-flat-list-out-of-a-list-of-lists
#     - Learned how to flatten lists from here
#
# - https://www.w3schools.com/python/python_dictionaries_add.asp
#     - review of dictionary and adding items to dictionary
#
# AI Collaboration
# ---
#
# I *recommend* not using LLMs to aid in this homework but instead use the documentation linked below, since it is vital for you to learn how to use Python properly. If, however, you get stuck and use generative AI or LLMs to help you complete this assignment, remember to cite it here with a short description of what you used it for, and which other resources you consulted (if any).
#
# Reflection
# ----
# Answer the following questions __after__ you complete this assignment (no more than 1 sentence per question required, this section is graded on completion):
#
# 1. Does this work reflect your best effort?
#
# -To complete this assignment, I had to review basic python and pandas documentation. I used them to help me finish the assignment, so i believe this assignment reflects my best effort
#
# 2. What was/were the most challenging part(s) of the assignment?
#
# -The most challenging part for me was task to create plot
#
# 3. If you want feedback, what function(s) or problem(s) would you like feedback on and why?
#
# -Better way to create the plot

# %% [markdown]
# Task 1: Python Warm-up (8 points)
# ----
#
# We'll warm-up by either learning about or reviewing `string`s, `for` loops, `range()`, and `list`s.
#
# Links to relevant documentation:
# - [strings](https://docs.python.org/3/library/string.html)
# - [Prof. Felix Muzny's notes on strings](https://muzny.github.io/csci1200-notes/03/5/strings.html)
# - [for loops](https://wiki.python.org/moin/ForLoop)
# - [Prof. Felix Muzny's notes on for loops](https://muzny.github.io/csci1200-notes/08/1/for_loops_basics.html)
# - [lists](https://docs.python.org/3/tutorial/datastructures.html)
# - [Prof. Felix Muzny's notes on lists](https://muzny.github.io/csci1200-notes/07/1/lists_basics.html)

# %%
# define a string variable, then
# using a for loop, iterate through the letters of a string

name = 'NishargGosai'

for i in name:
    print(i)
# Out:
# N
# i
# s
# h
# a
# r
# g
# G
# o
# s
# a
# i

# %%
# define a list variable, then
# using a for loop, iterate through the contents of a list

mylist = ['Domain',1,'xyz',0.5,'Arctic',[1,2,3]]

for i in mylist:
    print(i)
# Out:
# Domain
# 1
# xyz
# 0.5
# Arctic
# [1, 2, 3]

# %%
# define a string variable, then
# using a for loop and the range() function, print out every other token 
# (you may assume tokens are separated by spaces) in the string

alphabet = 'abcdefgh'

for i in range(0,len(alphabet),2):
    print(alphabet[i])
# Out:
# a
# c
# e
# g

# %%
# demonstrate the difference(s) between calling python's 
# str.split() function like str.split(' ') and str.split()

stringexample = 'Myfavoriteartistis 50 Cent.'

print(stringexample.split()) #split takes separator as an argument and by default its whitespace

print(stringexample.split('a')) #separator is 'a'
# Out:
# ['Myfavoriteartistis', '50', 'Cent.']
# ['Myf', 'vorite', 'rtistis 50 Cent.']

# %% [markdown]
# Task 2: Timing Python Functions (15 points)
# ----
#
# In this section, we'll explore efficiency and python data structures.
# You'll work on increasing your familiarity with `list`s, `dict`s, and [`Counter`](https://docs.python.org/3/library/collections.html#collections.Counter)s.
#
# Notice that in our python function headers, we include [type hints](https://docs.python.org/3/library/typing.html).

# %%
# for timing
import time

# for our fancier data structure
from collections import Counter

# for type hinting
from typing import Callable

# for graphing
import matplotlib.pyplot as plt

# for random number generation
import random

# %%
# provided
def timer(fun: Callable, tokens: list) -> float:
    """
    measure (in seconds) the time that it takes to run a
    function that operates on a list of strings (tokens)

    Args:
    fun: Callable
    tokens: list

    return:
    float (seconds)
    """
    start = time.time()
    fun(tokens)
    end = time.time()
    return end - start

# call like 
# len is the funtion that is being timed
print("That took:", timer(len, ["this", "is", "a", "test"]), "seconds!")
# Out:
# That took: 0.0 seconds!

# %%
# TODO: implement the following functions (function signatures are provided for you)

def count_list(tokens: list) -> dict:
    """
    Count the number of occurrences of each token in a list of tokens.
    Use the list.count() method.

    Args:
    tokens: list of items (often tokens)

    return:
    dict (mapping from token to count)
    """
    countdict={}
    for i in range(len(tokens)):
        countdict.update({tokens[i]:tokens.count(tokens[i])})
    return countdict

def count_dict(tokens: list) -> dict:
    """
    Count the number of occurrences of each token in a list of tokens.
    Do not use the list.count() method. Do not use a Counter.
    If you would like to use any method/function other than len, it must be
    okay'd with the teaching staff.

    Args:
    tokens: list of items (often tokens)

    return:
    dict (mapping from token to count)
    """
    countdict={}
    for i in tokens:
        if i in countdict.keys():
            countdict[i]=countdict[i]+1
        else:
            countdict[i]=1
    return countdict

def count_counter(tokens: list) -> Counter:
    """
    Count the number of occurrences of each token in a list of tokens.
    Use a Counter.
    Do not use the list.count() method or any other list/dict functions/methods.

    Args:
    tokens: list of items (often tokens)

    return:
    Counter (mapping from token to count)
    """
    c = Counter(tokens)
    return c

# %%
# TODO: verify that your count_* functions are correct and consistent with one another
# Make sure to test both if the list does not have duplicates and if it does


#list method
print(count_list('hello hello world i am your creation'.split()))
print(count_list('hello world i am your creation'.split()))

#dict method
print(count_dict('hello hello world i am your creation'.split()))
print(count_dict('hello world i am your creation'.split()))

#counter method
print(count_counter('hello hello world i am your creation'.split()))
print(count_counter('hello world i am your creation'.split()))
# Out:
# {'hello': 2, 'world': 1, 'i': 1, 'am': 1, 'your': 1, 'creation': 1}
# {'hello': 1, 'world': 1, 'i': 1, 'am': 1, 'your': 1, 'creation': 1}
# {'hello': 2, 'world': 1, 'i': 1, 'am': 1, 'your': 1, 'creation': 1}
# {'hello': 1, 'world': 1, 'i': 1, 'am': 1, 'your': 1, 'creation': 1}
# Counter({'hello': 2, 'world': 1, 'i': 1, 'am': 1, 'your': 1, 'creation': 1})
# Counter({'hello': 1, 'world': 1, 'i': 1, 'am': 1, 'your': 1, 'creation': 1})

# %%
# TODO: create a graph with three lines, one for each of the three count_* functions
# x-axis should be the number of items in the list given to the function (go up to at least 500)
# y-axis should be the time taken to run the function
# the graph should have a legend indicating which line is which (use plt.legend() to make this happen)
# you'll need to generate one (or more) list(s) of items to be counted.
# we recommend using the random module to generate random integers

list_sizes = range(10, 501, 10)
random_lists = [[random.randint(0, 10) for _ in range(size)] for size in list_sizes]

times_list = [timer(count_list, lst) for lst in random_lists]
times_dict = [timer(count_dict, lst) for lst in random_lists]
times_counter = [timer(count_counter, lst) for lst in random_lists]

plt.figure(figsize=(10, 6))
plt.plot(list_sizes, times_list, label='count_list', color='blue')
plt.plot(list_sizes, times_dict, label='count_dict', color='red')
plt.plot(list_sizes, times_counter, label='count_counter', color='green')

plt.xlabel('Number of Items in List')
plt.ylabel('Time Taken (seconds)')
plt.title('Performance Comparison of Counting Functions')
plt.legend()

plt.show()

# %% [markdown]
# Task 3: Real World Data (8 points)
# ----
#
# In this section, you'll find some real world text data *of interest to you* and run some analysis on this data. The data that you choose can include labels, but if it does, do not include those labels in your counts of tokens, etc.
#
#
# Size requirements:
# - your file must contain a minimum of 10,000 tokens (as measured by at least *one* of your tokenization schemes).
#
#
# Key vocabulary:
#
# __token__: The unit that we will operate on when processing text. Normally corresponds roughly to "words", and you can assume that this is the case for this homework.

# %%
# TODO
# the file should be in the same folder as this notebook because when you 
# submit this notebook, you will also submit the file and the backend of the 
# system expects them to be in the same directory
FILE = "Sarcasm_Headlines_Dataset_v2"

# %%
# read the contents of your file in, however you'd like
import pandas as pd
df = pd.read_json('/Users/nisharggosai/Desktop/sem 2/NLP/assignment/Sarcasm_Headlines_Dataset_v2.json', lines=True)
headlines = df['headline']
headlines
# Out:
# 0        thirtysomething scientists unveil doomsday clo...
# 1        dem rep. totally nails why congress is falling...
# 2        eat your veggies: 9 deliciously different recipes
# 3        inclement weather prevents liar from getting t...
# 4        mother comes pretty close to using word 'strea...
#                                ...
# 28614         jews to celebrate rosh hashasha or something
# 28615    internal affairs investigator disappointed con...
# 28616    the most beautiful acceptance speech this week...
# 28617    mars probe destroyed by orbiting spielberg-gat...
# 28618                   dad clarifies this not a food stop
# Name: headline, Length: 28619, dtype: object

# %%
# how many lines are in your file?
print("Number of lines:", headlines.shape[0])
# Out:
# Number of lines: 28619

# %%
# tokenize your data using the str.split() function. How many tokens are there? 

from itertools import chain

tokens = headlines.str.split(' ').tolist()

token_list = list(chain(*tokens))

token_list
# Out:
# ['thirtysomething',
#  'scientists',
#  'unveil',
#  'doomsday',
#  'clock',
#  'of',
#  'hair',
#  'loss',
#  'dem',
#  'rep.',
#  'totally',
#  'nails',
#  'why',
#  'congress',
#  'is',
#  'falling',
#  'short',
#  'on',
#  'gender,',
#  'racial',
#  'equality',
#  'eat',
#  'your',
#  'veggies:',
#  '9',
#  'deliciously',
#  'different',
#  'recipes',
#  'inclement',
#  'weather',
#  'prevents',
#  'liar',
#  'from',
#  'getting',
#  'to',
#  'work',
#  'mother',
#  'comes',
#  'pretty',
#  'close',
#  'to',
#  'using',
#  'word',
#  "'streaming'",
#  'correctly',
#  'my',
#  'white',
#  'inheritance',
#  '5',
#  'ways',
#  'to',
#  'file',
#  'your',
#  'taxes',
#  'with',
#  'less',
#  'stress',
#  'richard',
#  "branson's",
#  'global-warming',
#  'donation',
#  'nearly',
#  'as',
#  'much',
#  'as',
#  'cost',
#  'of',
#  'failed',
#  'balloon',
#  'trips',
#  'shadow',
#  'government',
#  'getting',
#  'too',
#  'large',
#  'to',
#  'meet',
#  'in',
#  'marriott',
#  'conference',
#  'room',
#  'b',
#  'lots',
#  'of',
#  'parents',
#  'know',
#  'this',
#  'scenario',
#  'this',
#  'lesbian',
#  'is',
#  'considered',
#  'a',
#  'father',
#  'in',
#  'indiana',
#  '(and',
#  'an',
#  'amazing',
#  'one',
#  'at',
#  'that)',
#  'amanda',
#  'peet',
#  'told',
#  'her',
#  'daughter',
#  'sex',
#  'is',
#  "'a",
#  'special',
#  "hug'",
#  'what',
#  'to',
#  'know',
#  'regarding',
#  'current',
#  'treatments',
#  'for',
#  'ebola',
#  'chris',
#  'christie',
#  'suggests',
#  'hillary',
#  'clinton',
#  'was',
#  'to',
#  'blame',
#  'for',
#  'boko',
#  "haram's",
#  'kidnapping',
#  'of',
#  'hundreds',
#  'of',
#  'schoolgirls',
#  'ford',
#  'develops',
#  'new',
#  'suv',
#  'that',
#  'runs',
#  'purely',
#  'on',
#  'gasoline',
#  'uber',
#  'ceo',
#  'travis',
#  'kalanick',
#  'stepping',
#  'down',
#  'from',
#  'trump',
#  'economic',
#  'advisory',
#  'council',
#  'area',
#  'boy',
#  'enters',
#  'jumping-and-touching-tops-of-doorways',
#  'phase',
#  'area',
#  'man',
#  'does',
#  'most',
#  'of',
#  'his',
#  'traveling',
#  'by',
#  'gurney',
#  'leave',
#  'no',
#  'person',
#  'with',
#  'disabilities',
#  'behind',
#  'lin-manuel',
#  'miranda',
#  'would',
#  'like',
#  'to',
#  'remind',
#  'you',
#  'to',
#  'put',
#  'your',
#  'phone',
#  'away',
#  '60',
#  'journalists',
#  'killed',
#  'in',
#  '2014',
#  'as',
#  'targeting',
#  'of',
#  'international',
#  'press',
#  'rises',
#  'guard',
#  'in',
#  'video',
#  'game',
#  'under',
#  'strict',
#  'orders',
#  'to',
#  'repeatedly',
#  'pace',
#  'same',
#  'stretch',
#  'of',
#  'hallway',
#  'how',
#  'to',
#  'live',
#  'to',
#  'be',
#  '110',
#  'cat',
#  'so',
#  'scared',
#  'in',
#  'shelter',
#  "won't",
#  'even',
#  'look',
#  'at',
#  'you',
#  'bill',
#  'clinton',
#  'shoots',
#  'down',
#  'republicans:',
#  "'i",
#  'strongly',
#  "supported'",
#  'obamacare',
#  'secret',
#  'service',
#  'agent',
#  'not',
#  'so',
#  'secret',
#  'about',
#  'being',
#  'david',
#  'alan',
#  'grier',
#  'fan',
#  'this',
#  'new',
#  'orange',
#  'era:',
#  'the',
#  'growing',
#  'divide',
#  'things',
#  'learned',
#  'in',
#  'the',
#  'first',
#  'month',
#  'of',
#  'having',
#  'a',
#  'baby',
#  'lamelo',
#  'ball',
#  'scores',
#  '92',
#  'points',
#  'in',
#  'a',
#  'single',
#  'high',
#  'school',
#  'basketball',
#  'game',
#  "i'm",
#  'bi.',
#  'it',
#  'took',
#  'me',
#  '21',
#  'years',
#  'to',
#  'come',
#  'out',
#  'of',
#  'the',
#  'closet',
#  'and',
#  'say',
#  'it.',
#  '10',
#  'essential',
#  'life',
#  'lessons',
#  'from',
#  'a',
#  'grandma',
#  'teenage',
#  'gunfight',
#  'with',
#  'isis',
#  'older',
#  'but',
#  'still',
#  'young',
#  'at',
#  'heart',
#  'leading',
#  'probability',
#  'researchers',
#  'confounded',
#  'by',
#  'three',
#  'coworkers',
#  'wearing',
#  'same',
#  'shirt',
#  'color',
#  'on',
#  'same',
#  'day',
#  'new',
#  'york',
#  'introduces',
#  'shoe-sharing',
#  'program',
#  'for',
#  "city's",
#  'pedestrians',
#  'beyoncé',
#  'sculpted',
#  'in',
#  'cheese',
#  'is',
#  'strangely',
#  'alluring',
#  'expansive',
#  'obama',
#  'state',
#  'of',
#  'the',
#  'union',
#  'speech',
#  'to',
#  'touch',
#  'on',
#  'patent',
#  'law,',
#  'entomology,',
#  'the',
#  'films',
#  'of',
#  'robert',
#  'altman',
#  'stars',
#  'with',
#  'gray',
#  'hair',
#  'prove',
#  'getting',
#  'older',
#  "isn't",
#  'all',
#  'that',
#  'bad',
#  'police',
#  'say',
#  'woman',
#  'made',
#  'up',
#  'story',
#  'of',
#  'attack',
#  'by',
#  'two',
#  'men,',
#  'one',
#  'wearing',
#  'a',
#  'trump',
#  'hat',
#  '(update)',
#  'naacp',
#  'demands',
#  'less',
#  'minority',
#  'representation',
#  'on',
#  'upn',
#  'the',
#  'best',
#  'clothes',
#  'for',
#  'the',
#  'man-child',
#  'in',
#  'your',
#  'life',
#  'florist',
#  'who',
#  'turned',
#  'away',
#  'gay',
#  'couple',
#  'wants',
#  'supreme',
#  'court',
#  'to',
#  'hear',
#  'her',
#  'case',
#  "we're",
#  'still',
#  'processing',
#  'that',
#  'ending',
#  'to',
#  'the',
#  'walking',
#  'dead',
#  '"strangers"',
#  'new',
#  'google',
#  'project',
#  'delivers',
#  'critical',
#  'info',
#  'to',
#  "refugees'",
#  'smartphones',
#  'new',
#  'history',
#  'textbook',
#  'makes',
#  'hatred',
#  'of',
#  'history',
#  'come',
#  'alive',
#  'for',
#  'students',
#  '10',
#  'ways',
#  'ridiculously',
#  'successful',
#  'people',
#  'think',
#  'differently',
#  'report:',
#  'bridge',
#  'probably',
#  'has',
#  'whole',
#  'mess',
#  'of',
#  'bats',
#  'under',
#  'there',
#  'texas',
#  'republicans',
#  'urge',
#  'trump-style',
#  'immigration',
#  'crackdown',
#  'tom',
#  'hanks',
#  'brags',
#  'how',
#  "'smokin'",
#  "hot'",
#  'rita',
#  'wilson',
#  'is',
#  'after',
#  '29',
#  'years',
#  'of',
#  'marriage',
#  'god',
#  'getting',
#  'strong',
#  'urge',
#  'to',
#  'bring',
#  'back',
#  'dinosaurs',
#  'lgbt',
#  'christians',
#  'speak',
#  'out:',
#  '"love',
#  'the',
#  'sinner,',
#  'hate',
#  'the',
#  'sin"',
#  "won't",
#  'cut',
#  'it',
#  'anymore',
#  'handshake',
#  'comes',
#  'in',
#  'at',
#  'unusually',
#  'high',
#  'angle,',
#  'velocity',
#  'mom',
#  'keeps',
#  'sending',
#  'newspaper',
#  'clippings',
#  'about',
#  'former',
#  'classmates',
#  'who',
#  'have',
#  'been',
#  'murdered',
#  'report:',
#  'make',
#  'it',
#  'stop',
#  'coed',
#  'rec',
#  'softball',
#  'team',
#  'having',
#  'trouble',
#  'finding',
#  'enough',
#  'hyper-competitive',
#  'men',
#  'to',
#  'ruin',
#  'experience',
#  'brutalist',
#  'beaver',
#  'constructs',
#  'paul',
#  'rudolph-inspired',
#  'dam',
#  'jindal:',
#  'westboro',
#  'baptist',
#  'members',
#  'who',
#  'protest',
#  'funerals',
#  'face',
#  'arrest',
#  'gop',
#  'congressman',
#  'may',
#  'not',
#  'vote',
#  'for',
#  'president',
#  'at',
#  'all',
#  'donald',
#  "trump's",
#  'latest',
#  'attempt',
#  'to',
#  'repeal',
#  'obamacare',
#  'makes',
#  'seth',
#  'meyers',
#  'sick',
#  'suicide',
#  'bombing:',
#  'can',
#  'parents',
#  'spot',
#  'the',
#  'warning',
#  'signs?',
#  'state',
#  'department',
#  'warns',
#  'americans',
#  'traveling',
#  'abroad',
#  'to',
#  'avoid',
#  'lame',
#  'amsterdam',
#  'windmill',
#  'tour',
#  'meatless',
#  'monday:',
#  'portuguese',
#  'mashup',
#  'you',
#  'can',
#  'now',
#  'message',
#  'the',
#  'president',
#  'on',
#  'facebook',
#  'families',
#  'of',
#  'missing',
#  'flight',
#  'passengers',
#  'just',
#  'hoping',
#  'media',
#  'gets',
#  'closure',
#  'it',
#  'needs',
#  'fender',
#  'releases',
#  'new',
#  'hybrid',
#  'gas-electric',
#  'guitar',
#  'romney',
#  'volunteers',
#  'going',
#  'door-to-door',
#  'to',
#  'let',
#  'obama',
#  'supporters',
#  'know',
#  "president's",
#  'dead',
#  'friday',
#  'talking',
#  'points',
#  '--',
#  'prelude',
#  'to',
#  'silly',
#  'season',
#  'meet',
#  'sparkle,',
#  'the',
#  '2-year-old',
#  "who's",
#  'your',
#  'next',
#  'style',
#  'crush',
#  "hollywood's",
#  'biggest',
#  'stars',
#  'endure',
#  'long',
#  'lines',
#  'at',
#  'oscars',
#  'security',
#  'screening',
#  'congresswoman',
#  'fights',
#  'for',
#  'gun',
#  'control',
#  'because',
#  'she',
#  'almost',
#  'lost',
#  'her',
#  'life',
#  'to',
#  'gun',
#  'violence',
#  'how',
#  'to',
#  'raise',
#  'kids',
#  'who',
#  'can',
#  "'love",
#  'and',
#  'be',
#  "loved'",
#  'want',
#  'to',
#  'make',
#  'meetings',
#  'more',
#  'productive?',
#  'start',
#  'walking',
#  'elizabeth',
#  "warren's",
#  'pick',
#  'wins',
#  "ohio's",
#  'democratic',
#  'gubernatorial',
#  'primary',
#  'biting',
#  'argument',
#  'over',
#  'trump',
#  'may',
#  'cost',
#  'man',
#  'his',
#  'ear',
#  'longtime',
#  'reader',
#  'of',
#  'lib-slaves.info',
#  'sick',
#  'of',
#  'mainstream',
#  'bias',
#  'on',
#  'sites',
#  'like',
#  'wideawakepatriot.com',
#  'beijing',
#  'fire',
#  'department',
#  'extinguishes',
#  'massive',
#  'five-alarm',
#  'burning',
#  'cloud',
#  'of',
#  'smog',
#  'china',
#  'intensifies',
#  'pressure',
#  'on',
#  'north',
#  'korea',
#  'defiant',
#  'sanders',
#  'camp:',
#  'it',
#  "ain't",
#  'over',
#  'when',
#  'the',
#  'sheep',
#  'are',
#  'watching',
#  'over',
#  'your',
#  'mind',
#  'first',
#  'up',
#  'at',
#  'the',
#  'toronto',
#  'film',
#  'festival:',
#  'jake',
#  "gyllenhaal's",
#  "'demolition,'",
#  'the',
#  'stunning',
#  "'lobster'",
#  'and',
#  'more',
#  'super',
#  'pac',
#  'men:',
#  'how',
#  'political',
#  'consultants',
#  'took',
#  'a',
#  'texas',
#  'oilman',
#  'on',
#  'a',
#  'wild',
#  'ride',
#  "'active",
#  'shooter',
#  'at',
#  "large,'",
#  'reports',
#  'endless',
#  'background',
#  'hum',
#  'of',
#  'modern',
#  'american',
#  'life',
#  'david',
#  'axelrod',
#  'suggests',
#  'hillary',
#  'clinton',
#  'will',
#  'be',
#  'seen',
#  'as',
#  'less',
#  'complex',
#  'alternative',
#  'to',
#  'obama',
#  'sleater-kinney',
#  'just',
#  'made',
#  "bowie's",
#  "'rebel",
#  "rebel'",
#  'the',
#  'political',
#  'anthem',
#  'of',
#  '2017',
#  'kirsten',
#  'gillibrand',
#  'only',
#  'regrets',
#  'not',
#  'calling',
#  'for',
#  'al',
#  'franken',
#  'to',
#  'quit',
#  'sooner',
#  'wells',
#  'fargo',
#  'sued',
#  'for',
#  'barring',
#  'daca',
#  'recipients',
#  'from',
#  'student',
#  'loans',
#  'historical',
#  'archives:',
#  'amazing',
#  'publick',
#  'spectacle!',
#  'israel',
#  'passes',
#  'law',
#  'cementing',
#  'itself',
#  'as',
#  'exclusive',
#  'nation-state',
#  'of',
#  'benjamin',
#  'netanyahu',
#  'onion',
#  'social',
#  'cracks',
#  'down',
#  'on',
#  'sexual',
#  'harassment',
#  'by',
#  'banning',
#  'all',
#  'women',
#  'from',
#  'platform',
#  'exclusive',
#  'promo',
#  'hints',
#  'stephen',
#  'colbert',
#  'will',
#  'unleash',
#  'on',
#  'trump',
#  'in',
#  'live',
#  'election',
#  'show',
#  'banksy',
#  'returns',
#  'to',
#  'new',
#  'york',
#  'city',
#  'with',
#  'one',
#  'of',
#  'his',
#  'trademark',
#  'rats',
#  'bobby',
#  "jindal's",
#  'biggest',
#  'donors',
#  'benefited',
#  'from',
#  'his',
#  'administration',
#  'drunk',
#  'driver',
#  'in',
#  'the',
#  'zone',
#  'egyptian',
#  'woman',
#  'wishes',
#  'screaming',
#  'protester',
#  'husband',
#  'would',
#  'go',
#  'bonkers',
#  'for',
#  'her',
#  'once',
#  'in',
#  'a',
#  'while',
#  'meet',
#  'the',
#  'millennial',
#  'men',
#  'who',
#  'love',
#  'hillary',
#  'clinton',
#  'number',
#  'of',
#  'homeless',
#  'students',
#  'in',
#  'america',
#  'is',
#  'rising',
#  'rapidly',
#  'report:',
#  'majority',
#  'of',
#  'instances',
#  'of',
#  'people',
#  'getting',
#  'lives',
#  'back',
#  'on',
#  'track',
#  'occur',
#  'immediately',
#  'after',
#  'visit',
#  'to',
#  'buffalo',
#  'wild',
#  'wings',
#  'groundbreaking',
#  'study',
#  'finds',
#  'gratification',
#  'can',
#  'be',
#  'deliberately',
#  'postponed',
#  'nick',
#  'cannon',
#  'responds',
#  'to',
#  'mariah',
#  "carey's",
#  'engagement',
#  'in',
#  'the',
#  'best',
#  'way',
#  'midlife',
#  'obesity',
#  'may',
#  'speed',
#  'up',
#  "alzheimer's",
#  'report:',
#  '70%',
#  'of',
#  'trump',
#  'endorsements',
#  'made',
#  'after',
#  'staring',
#  'at',
#  'bedroom',
#  'ceiling',
#  'for',
#  '4',
#  ...]

# %%
print('The number of tokens are',len(token_list))
# Out:
# The number of tokens are 287674

# %% [markdown]
# Find five specific examples of difficult-to-tokenize sequences of letters in your data.
# - Example 1 thirtysomething
# - Example 2 veggies:
# - Example 3 (and
# - Example 4 that)
# - Example 5 hug'

# %% [markdown]
# Task 4: Data Write-Up (6 points)
# ---
#
# Every time you use a data set in an NLP application (or in any software application), you should be able to answer a set of questions about that data. Answer these now. Default to no more than 1 sentence per question needed. If more explanation is necessary, do give it.

# %% [markdown]
# 1. Where did you get the data from?
# -Got the dataset from Kaggle, https://www.kaggle.com/datasets/rmisra/news-headlines-dataset-for-sarcasm-detection
#
#
# 2. How was the data collected (where did the people acquiring the data get it from and how)?
# -News Headlines dataset for Sarcasm Detection is collected from two news website. TheOnion aims at producing sarcastic versions of current events and we collected all the headlines from News in Brief and News in Photos categories (which are sarcastic). We collect real (and non-sarcastic) news headlines from HuffPost.
#
#
# 3. How large is the dataset? (copy # of lines and # of tokens from above)
# -28619 rows × 3 columns
# Number of lines is 28619
# Number of tokens for headlines column is 287674
#
#
# 4. Is your dataset a subset of a larger dataset or the entirety of a dataset? (e.g. the first half of reviews from the dataset.... vs. all reviews from ...)
# -Dataset is headlines from the larger dataset which contains headlines, the news article where the headline was from and the value 0 or 1 to indicate sarcastic headline or not
#
#
# 5. What is your data? (i.e. newswire, tweets, books, blogs, etc)
# -Data is a collection of headlines from news articles both sarcastics or not
#
#
# 6. Who produced the data? (who were the authors of the text? Your answer might be a specific person or a particular group of people)
# -Misra, Rishabh and Jigyasa Grover. "Sculpting Data for ML: The first act of Machine Learning." ISBN 9798585463570 (2021).
